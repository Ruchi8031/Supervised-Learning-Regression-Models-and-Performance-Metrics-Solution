# %% [markdown]
# Question 1: What is Simple Linear Regression (SLR)? Explain its purpose.

# %% [markdown]
#   - Simple Linear Regression is a statistical method used to model the relationship between one independent variable (X) and one dependent variable (Y).
#
#   - It assumes a linear relationship between X and Y.
#
#   - Purpose:
#
#   - To predict the value of Y based on X.
#
#   - To understand how changes in X affect Y.

# %% [markdown]
# Question 2: What are the key assumptions of Simple Linear Regression?

# %% [markdown]
#   - Linearity: Relationship between X and Y is linear.
#
#   - Independence: Observations are independent.
#
#   - Homoscedasticity: Constant variance of errors.
#
#   - Normality: Residuals are normally distributed.
#
#   - No multicollinearity (automatically satisfied in SLR since only one predictor exists).

# %% [markdown]
# Question 3: Write the mathematical equation for a simple linear regression model and explain each term.

# %% [markdown]
#   - Y= β0 + β1 X + ε
# 	​
#   - Y = Dependent variable (output)
#
#   - X = Independent variable (input)
#
#   - β₀ = Intercept (value of Y when X = 0)
#
#   - β₁ = Slope (change in Y per unit change in X)
#
#   - ε = Error term (residual)

# %% [markdown]
# Question 4: Provide a real-world example where simple linear regression can be applied.

# %% [markdown]
#   - Predicting house price based on area (square feet).
#
#   - Predicting salary based on years of experience.
#
#   - Predicting electricity consumption based on temperature.

# %% [markdown]
# Question 5: What is the method of least squares in linear regression?

# %% [markdown]
#   - It is an optimization technique used to find the best-fitting regression line.
#
#   - It minimizes the sum of squared differences between actual and predicted values.
#
#   - Objective:min∑(Yactual​−Ypredicted​)2
